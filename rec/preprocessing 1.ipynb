# %%
import numpy as np
import pandas as pd

# %%
def convert_dtype_int(x):
    if not x:
        return None
    try:
        return int(x)
    except:        
        return None
def convert_dtype_str(x):
    if not x:
        return None
    try:
        return str(x)
    except:        
        return None
def convert_dtype_date(x):
    if not x:
        return None
    try:
        return pd.to_datetime(x, format='%Y', errors='coerce')
    except:        
        return None

# %%
books = pd.read_csv("BX-Books.csv", sep=';', encoding="latin-1", 
                    converters = {'Year-Of-Publication': convert_dtype_int},
                    on_bad_lines='skip')
# users = pd.read_csv("BX-Users.csv", sep=';', encoding="latin-1", 
#                     on_bad_lines='skip')
# ratings = pd.read_csv("BX-Book-Ratings.csv", sep=';', encoding="latin-1", 
#                     on_bad_lines='skip')

# %%
# books = pd.read_csv('BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# books.columns = ['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher', 'imageUrlS', 'imageUrlM', 'imageUrlL']
# users = pd.read_csv('BX-Users.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# users.columns = ['userID', 'Location', 'Age']
# ratings = pd.read_csv('BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# ratings.columns = ['userID', 'ISBN', 'bookRating']

# %%
books.columns = ['isbn', 'title', 'author', 'publication', 'publisher', 'imageUrlS', 'imageUrlM', 'imageUrlL']
display(books)
print(books.isna().sum())
books1 = books.dropna()
print(books1.isna().sum())
books1.to_csv('b1.csv', encoding='utf-8', index=False)
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  publication  \
# 0         Mark P. O. Morford       2002.0
# 1       Richard Bruce Wright       2001.0
# 2               Carlo D'Este       1991.0
# 3           Gina Bari Kolata       1999.0
# 4            E. J. W. Barber       1999.0
# ...                      ...          ...
# 271355        Paula Danziger       1988.0
# 271356            Teri Sloat       1991.0
# 271357      Christine Wicker       2004.0
# 271358                 Plato       1996.0
# 271359   Christopher  Biffle       2000.0
#
#                                                publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                                 imageUrlS  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                                 imageUrlM  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                                 imageUrlL
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]
# isbn           0
# title          0
# author         1
# publication    3
# publisher      2
# imageUrlS      0
# imageUrlM      0
# imageUrlL      3
# dtype: int64
# isbn           0
# title          0
# author         0
# publication    0
# publisher      0
# imageUrlS      0
# imageUrlM      0
# imageUrlL      0
# dtype: int64

# %%
b2 = pd.read_csv("book_data.csv")
b2.columns = ['authors', 'desc', 'edition', 'format', 'isbn', 'pages', 'rating', 'rating_count', 'review_count', 'title', 'genres', 'img_url']
display(b2)
# Out:
#                                                  authors  \
# 0                                        Suzanne Collins
# 1                             J.K. Rowling|Mary GrandPré
# 2                                             Harper Lee
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                        Stephenie Meyer
# ...                                                  ...
# 54296                                      Howard Megdal
# 54297                                      Howard Megdal
# 54298                                      Howard Megdal
# 54299                             Mimi Baird|Eve Claxton
# 54300                                         Leah Price
#
#                                                     desc  \
# 0      Winning will make you famous. Losing means cer...
# 1      There is a door at the end of a silent corrido...
# 2      The unforgettable novel of a childhood in a sl...
# 3      «È cosa ormai risaputa che a uno scapolo in po...
# 4      About three things I was absolutely positive.F...
# ...                                                  ...
# 54296  In this fearless and half-crazy story, Howard ...
# 54297  From the icons of the game to the players who ...
# 54298                                                NaN
# 54299  Soon to be a major motion picture, from Brad P...
# 54300  The Anthology and the Rise of the Novel brings...
#
#                                   edition          format         isbn  \
# 0                                     NaN       Hardcover  9.78044E+12
# 1                              US Edition       Paperback  9.78044E+12
# 2                        50th Anniversary       Paperback  9.78006E+12
# 3      Modern Library Classics, USA / CAN       Paperback  9.78068E+12
# 4                                     NaN       Paperback  9.78032E+12
# ...                                   ...             ...          ...
# 54296                                 NaN       Hardcover  9.78161E+12
# 54297                                 NaN       Hardcover  9.78006E+12
# 54298                                 NaN  Kindle Edition          NaN
# 54299                                 NaN       Hardcover   9.7808E+12
# 54300                                 NaN       Paperback  9.78052E+12
#
#            pages  rating  rating_count  review_count  \
# 0      374 pages    4.33       5519135        160706
# 1      870 pages    4.48       2041594         33264
# 2      324 pages    4.27       3745197         79450
# 3      279 pages    4.25       2453620         54322
# 4      498 pages    3.58       4281268         97991
# ...          ...     ...           ...           ...
# 54296  256 pages    3.37            27             9
# 54297  256 pages    3.97            34             5
# 54298        NaN    3.66            32             3
# 54299  272 pages    3.82           867           187
# 54300  236 pages    3.58            12             3
#
#                                                    title  \
# 0                                       The Hunger Games
# 1              Harry Potter and the Order of the Phoenix
# 2                                  To Kill a Mockingbird
# 3                                    Pride and Prejudice
# 4                                               Twilight
# ...                                                  ...
# 54296  Taking the Field: A Fan's Quest to Run the Tea...
# 54297  The Baseball Talmud: Koufax, Greenberg, and th...
# 54298  Wilpon's Folly - The Story of a Man, His Fortu...
# 54299  He Wanted the Moon: The Madness and Medical Ge...
# 54300  The Anthology and the Rise of the Novel: From ...
#
#                                                   genres  \
# 0      Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                            Fantasy|Young Adult|Fiction
# 2      Classics|Fiction|Historical|Historical Fiction...
# 3                               Classics|Fiction|Romance
# 4      Young Adult|Fantasy|Romance|Paranormal|Vampire...
# ...                                                  ...
# 54296  Sports|Baseball|Sports and Games|Sports|Nonfic...
# 54297                 Nonfiction|Sports and Games|Sports
# 54298                          Sports|Baseball|Abandoned
# 54299  Nonfiction|Autobiography|Memoir|Biography|Psyc...
# 54300  Criticism|Literary Criticism|Philosophy|Theory...
#
#                                                  img_url
# 0      https://images.gr-assets.com/books/1447303603l...
# 1      https://images.gr-assets.com/books/1255614970l...
# 2      https://images.gr-assets.com/books/1361975680l...
# 3      https://images.gr-assets.com/books/1320399351l...
# 4      https://images.gr-assets.com/books/1361039443l...
# ...                                                  ...
# 54296  https://images.gr-assets.com/books/1312074392l...
# 54297  https://images.gr-assets.com/books/1348841629l...
# 54298  https://images.gr-assets.com/books/1394277097l...
# 54299  https://images.gr-assets.com/books/1403192135l...
# 54300  https://images.gr-assets.com/books/1349014225l...
#
# [54301 rows x 12 columns]

# %%
b1 = pd.read_csv("b1.csv")
print(len(b1))
print(len(b2))
# Out:
# 271354
# 54301

# %%
result = pd.merge(b1, b2, on="title")
# display(result)
print(result.columns)
print(result.shape)
features = ['isbn_x', 'title', 'author', 'publication', 'publisher', 'desc', 
            'format', 'pages', 'rating', 'rating_count', 'review_count', 'genres', 'img_url']
r1 = result[features]
display(r1)
# Out:
# Index(['isbn_x', 'title', 'author', 'publication', 'publisher', 'imageUrlS',
#        'imageUrlM', 'imageUrlL', 'authors', 'desc', 'edition', 'format',
#        'isbn_y', 'pages', 'rating', 'rating_count', 'review_count', 'genres',
#        'img_url'],
#       dtype='object')
# (32826, 19)
#            isbn_x                   title                 author  publication  \
# 0      0399135782  The Kitchen God's Wife                Amy Tan       1991.0
# 1      0399135782  The Kitchen God's Wife                Amy Tan       1991.0
# 2      080410753X  The Kitchen God's Wife                Amy Tan       1992.0
# 3      080410753X  The Kitchen God's Wife                Amy Tan       1992.0
# 4      080410753x  The Kitchen God's Wife                Amy Tan       1992.0
# ...           ...                     ...                    ...          ...
# 32821  0441702902                Radiance           Anne Maybury       1980.0
# 32822  0441702902                Radiance           Anne Maybury       1980.0
# 32823  0345298608        The Broken Sword       Northam Anderson       1981.0
# 32824  0451521390              Pathfinder  James Fenimore Cooper       1982.0
# 32825  0451521390              Pathfinder  James Fenimore Cooper       1982.0
#
#               publisher                                               desc  \
# 0      Putnam Pub Group  Winnie and Helen have kept each other's worst ...
# 1      Putnam Pub Group  Winnie and Helen have kept each others worst s...
# 2             Ivy Books  Winnie and Helen have kept each other's worst ...
# 3             Ivy Books  Winnie and Helen have kept each others worst s...
# 4             Ivy Books  Winnie and Helen have kept each other's worst ...
# ...                 ...                                                ...
# 32821         Ace Books  THE PRINCE OF NO VALUEBrishen Khaskem, prince ...
# 32822         Ace Books  Radiance is a decopunk pulp SF alt-history spa...
# 32823     Del Rey Books  Thor broke the sword Tyrfing to save the roots...
# 32824       Signet Book  A powerful secret. A dangerous path. Rigg is w...
# 32825       Signet Book  Length: 17 hrs and 46 mins Rigg is well traine...
#
#                format      pages  rating  rating_count  review_count  \
# 0           Paperback  416 pages    3.99         66434          1932
# 1           Hardcover  415 pages    3.99         66457          1932
# 2           Paperback  416 pages    3.99         66434          1932
# 3           Hardcover  415 pages    3.99         66457          1932
# 4           Paperback  416 pages    3.99         66434          1932
# ...               ...        ...     ...           ...           ...
# 32821  Kindle Edition  297 pages    4.12         21081          2195
# 32822       Hardcover  429 pages    3.77          3213           839
# 32823       Paperback  274 pages    3.86          4465           376
# 32824       Hardcover  657 pages    3.98         20260          2210
# 32825   Audible Audio   18 pages    3.98         20261          2210
#
#                                                   genres  \
# 0      Fiction|Historical|Historical Fiction|Cultural...
# 1      Fiction|Historical|Historical Fiction|Cultural...
# 2      Fiction|Historical|Historical Fiction|Cultural...
# 3      Fiction|Historical|Historical Fiction|Cultural...
# 4      Fiction|Historical|Historical Fiction|Cultural...
# ...                                                  ...
# 32821  Fantasy|Romance|Romance|Fantasy Romance|Fantas...
# 32822  Science Fiction|Fantasy|Fiction|Science Fictio...
# 32823  Fantasy|Fiction|Fantasy|Mythology|Classics|Fan...
# 32824        Fantasy|Science Fiction|Young Adult|Fiction
# 32825        Fantasy|Science Fiction|Young Adult|Fiction
#
#                                                  img_url
# 0      https://images.gr-assets.com/books/1434152599l...
# 1      https://images.gr-assets.com/books/1387711980l...
# 2      https://images.gr-assets.com/books/1434152599l...
# 3      https://images.gr-assets.com/books/1387711980l...
# 4      https://images.gr-assets.com/books/1434152599l...
# ...                                                  ...
# 32821  https://images.gr-assets.com/books/1422721500l...
# 32822  https://images.gr-assets.com/books/1412283972l...
# 32823  https://images.gr-assets.com/books/1408925194l...
# 32824  https://images.gr-assets.com/books/1388269881l...
# 32825  https://images.gr-assets.com/books/1513633925l...
#
# [32826 rows x 13 columns]

# %%
# r1.duplicated(['title'])
# r1['isbn_x'].is_unique()
# r1[r1.duplicated(subset=['title'])]
# print(r1.isna().sum())
r2 = r1.dropna(subset=['pages', 'genres', 'desc', 'format'])
# print(r2.isna().sum())
# print(r2.shape)
r2.duplicated(['title'])
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32821     True
# 32822     True
# 32823    False
# 32824    False
# 32825     True
# Length: 31356, dtype: bool

# %%
r3 = r2.drop_duplicates(subset='title', keep='first')
r3.duplicated(['title']).sum()
print(r3.columns)
r3.columns = ['isbn', 'title', 'author', 'publication', 'publisher',
       'desc', 'format', 'pages', 'rating', 'rating_count', 'review_count',
       'genres', 'img_url']
display(r3)
r3.to_csv('r3.csv', encoding='utf-8', index=False)
# Out:
# Index(['isbn_x', 'title', 'author', 'publication', 'publisher', 'desc',
#        'format', 'pages', 'rating', 'rating_count', 'review_count', 'genres',
#        'img_url'],
#       dtype='object')
#              isbn                                              title  \
# 0      0399135782                             The Kitchen God's Wife
# 10     0440234743                                      The Testament
# 17     0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 18     0345402871                                           Airframe
# 23     0345417623                                           Timeline
# ...           ...                                                ...
# 32816  0590974092                              Sarah, Plain and Tall
# 32818  2859406735                                           Armadale
# 32819  0441702902                                           Radiance
# 32823  0345298608                                   The Broken Sword
# 32824  0451521390                                         Pathfinder
#
#                       author  publication           publisher  \
# 0                    Amy Tan       1991.0    Putnam Pub Group
# 10              John Grisham       1999.0                Dell
# 17                 The Onion       1999.0  Three Rivers Press
# 18          Michael Crichton       1997.0    Ballantine Books
# 23          MICHAEL CRICHTON       2000.0    Ballantine Books
# ...                      ...          ...                 ...
# 32816    Patricia MacLachlan       1996.0          Scholastic
# 32818         Wilkie Collins       2000.0           PhÃ?Â©bus
# 32819           Anne Maybury       1980.0           Ace Books
# 32823       Northam Anderson       1981.0       Del Rey Books
# 32824  James Fenimore Cooper       1982.0         Signet Book
#
#                                                     desc  \
# 0      Winnie and Helen have kept each other's worst ...
# 10     In a plush Virginia office, a rich, angry old ...
# 17     The Onion has quickly become the world's most ...
# 18     The twin jet plane en route to Denver from Hon...
# 23     In an Arizona desert, a man wanders in a daze,...
# ...                                                  ...
# 32816  This beloved Newbery Medal–winning book is the...
# 32818  The novel has a convoluted plot about two dist...
# 32819  Riley has crossed the bridge into the afterlif...
# 32823  Thor broke the sword Tyrfing to save the roots...
# 32824  A powerful secret. A dangerous path. Rigg is w...
#
#                       format      pages  rating  rating_count  review_count  \
# 0                  Paperback  416 pages    3.99         66434          1932
# 10                 Paperback  535 pages    3.84         92234          2538
# 17                 Paperback  164 pages    4.17         12031           128
# 18                 Paperback  431 pages    3.69         69392          1658
# 23     Mass Market Paperback  489 pages    3.84        170382          4002
# ...                      ...        ...     ...           ...           ...
# 32816              Paperback   64 pages    3.73         63238          2310
# 32818              Paperback  721 pages    3.89          5307           293
# 32819              Paperback  183 pages    3.57         14263          1391
# 32823              Paperback  274 pages    3.86          4465           376
# 32824              Hardcover  657 pages    3.98         20260          2210
#
#                                                   genres  \
# 0      Fiction|Historical|Historical Fiction|Cultural...
# 10                              Fiction|Mystery|Thriller
# 17     Humor|Fiction|Humor|Comedy|Politics|Humor|Funn...
# 18     Fiction|Thriller|Mystery|Science Fiction|Suspense
# 23     Fiction|Science Fiction|Thriller|Science Ficti...
# ...                                                  ...
# 32816  Historical|Historical Fiction|Childrens|Fictio...
# 32818  Classics|Fiction|Mystery|Historical|Victorian|...
# 32819             Fantasy|Young Adult|Fantasy|Paranormal
# 32823  Fantasy|Fiction|Fantasy|Mythology|Classics|Fan...
# 32824        Fantasy|Science Fiction|Young Adult|Fiction
#
#                                                  img_url
# 0      https://images.gr-assets.com/books/1434152599l...
# 10     https://images.gr-assets.com/books/1403174228l...
# 17     https://images.gr-assets.com/books/1388195124l...
# 18     https://images.gr-assets.com/books/1405420599l...
# 23     https://images.gr-assets.com/books/1405420745l...
# ...                                                  ...
# 32816  https://images.gr-assets.com/books/1327254558l...
# 32818  https://images.gr-assets.com/books/1348113675l...
# 32819  https://images.gr-assets.com/books/1317066100l...
# 32823  https://images.gr-assets.com/books/1408925194l...
# 32824  https://images.gr-assets.com/books/1388269881l...
#
# [9344 rows x 13 columns]

# %%
r = pd.read_csv("r3.csv")
display(r)
# Out:
#             isbn                                              title  \
# 0     0399135782                             The Kitchen God's Wife
# 1     0440234743                                      The Testament
# 2     0609804618  Our Dumb Century: The Onion Presents 100 Years...
# 3     0345402871                                           Airframe
# 4     0345417623                                           Timeline
# ...          ...                                                ...
# 9339  0590974092                              Sarah, Plain and Tall
# 9340  2859406735                                           Armadale
# 9341  0441702902                                           Radiance
# 9342  0345298608                                   The Broken Sword
# 9343  0451521390                                         Pathfinder
#
#                      author  publication           publisher  \
# 0                   Amy Tan       1991.0    Putnam Pub Group
# 1              John Grisham       1999.0                Dell
# 2                 The Onion       1999.0  Three Rivers Press
# 3          Michael Crichton       1997.0    Ballantine Books
# 4          MICHAEL CRICHTON       2000.0    Ballantine Books
# ...                     ...          ...                 ...
# 9339    Patricia MacLachlan       1996.0          Scholastic
# 9340         Wilkie Collins       2000.0           PhÃ?Â©bus
# 9341           Anne Maybury       1980.0           Ace Books
# 9342       Northam Anderson       1981.0       Del Rey Books
# 9343  James Fenimore Cooper       1982.0         Signet Book
#
#                                                    desc  \
# 0     Winnie and Helen have kept each other's worst ...
# 1     In a plush Virginia office, a rich, angry old ...
# 2     The Onion has quickly become the world's most ...
# 3     The twin jet plane en route to Denver from Hon...
# 4     In an Arizona desert, a man wanders in a daze,...
# ...                                                 ...
# 9339  This beloved Newbery Medal–winning book is the...
# 9340  The novel has a convoluted plot about two dist...
# 9341  Riley has crossed the bridge into the afterlif...
# 9342  Thor broke the sword Tyrfing to save the roots...
# 9343  A powerful secret. A dangerous path. Rigg is w...
#
#                      format      pages  rating  rating_count  review_count  \
# 0                 Paperback  416 pages    3.99         66434          1932
# 1                 Paperback  535 pages    3.84         92234          2538
# 2                 Paperback  164 pages    4.17         12031           128
# 3                 Paperback  431 pages    3.69         69392          1658
# 4     Mass Market Paperback  489 pages    3.84        170382          4002
# ...                     ...        ...     ...           ...           ...
# 9339              Paperback   64 pages    3.73         63238          2310
# 9340              Paperback  721 pages    3.89          5307           293
# 9341              Paperback  183 pages    3.57         14263          1391
# 9342              Paperback  274 pages    3.86          4465           376
# 9343              Hardcover  657 pages    3.98         20260          2210
#
#                                                  genres  \
# 0     Fiction|Historical|Historical Fiction|Cultural...
# 1                              Fiction|Mystery|Thriller
# 2     Humor|Fiction|Humor|Comedy|Politics|Humor|Funn...
# 3     Fiction|Thriller|Mystery|Science Fiction|Suspense
# 4     Fiction|Science Fiction|Thriller|Science Ficti...
# ...                                                 ...
# 9339  Historical|Historical Fiction|Childrens|Fictio...
# 9340  Classics|Fiction|Mystery|Historical|Victorian|...
# 9341             Fantasy|Young Adult|Fantasy|Paranormal
# 9342  Fantasy|Fiction|Fantasy|Mythology|Classics|Fan...
# 9343        Fantasy|Science Fiction|Young Adult|Fiction
#
#                                                 img_url
# 0     https://images.gr-assets.com/books/1434152599l...
# 1     https://images.gr-assets.com/books/1403174228l...
# 2     https://images.gr-assets.com/books/1388195124l...
# 3     https://images.gr-assets.com/books/1405420599l...
# 4     https://images.gr-assets.com/books/1405420745l...
# ...                                                 ...
# 9339  https://images.gr-assets.com/books/1327254558l...
# 9340  https://images.gr-assets.com/books/1348113675l...
# 9341  https://images.gr-assets.com/books/1317066100l...
# 9342  https://images.gr-assets.com/books/1408925194l...
# 9343  https://images.gr-assets.com/books/1388269881l...
#
# [9344 rows x 13 columns]
